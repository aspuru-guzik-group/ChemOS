# %%
# restore data
import pickle
data  = pickle.load( open('training_data', 'rb'))
words = data['words']
classes = data['classes']
train_x = data['train_x']
train_y = data['train_y']

# %%
# import chatbot files
import json 
with open('intents.json') as json_data:
    intents = json.load(json_data)

# %%
# define model
tf.reset_default_graph()
net = tflearn.input_data(shape = [None, len(train_x[0])])
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, len(train_y[0]), activation = 'softmax')
net = tflearn.regression(net)

# define model and setup
model = tflearn.DNN(net, tensorboard_dir = 'tflearn_logs')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-75d4710dd530> in <module>()
#       1 # define model
# ----> 2 tf.reset_default_graph()
#       3 net = tflearn.input_data(shape = [None, len(train_x[0])])
#       4 net = tflearn.fully_connected(net, 8)
#       5 net = tflearn.fully_connected(net, 8)
#
# NameError: name 'tf' is not defined

# %%
# load the trained model
model.load('./ChatBotModel/model.tflearn')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4165525610a9> in <module>()
#       1 # load the trained model
# ----> 2 model.load('./ChatBotModel/model.tflearn')
#
# NameError: name 'model' is not defined
